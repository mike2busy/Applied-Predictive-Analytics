# %%
# !pip install -q yfinance
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# For reading stock data from yahoo
from pandas_datareader.data import DataReader
import yfinance as yf
from pandas_datareader import data as pdr

yf.pdr_override()

# %%
# For time stamps
from datetime import datetime


# The tech stocks we'll use for this analysis
tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN']

# Set up End and Start times for data grab
tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN']

end = datetime.now()
start = datetime(end.year - 5, end.month, end.day)

for stock in tech_list:
    globals()[stock] = yf.download(stock, start, end)

company_list = [AAPL, GOOG, MSFT, AMZN]
company_name = ["APPLE", "GOOGLE", "MICROSOFT", "AMAZON"]

for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name

df = pd.concat(company_list, axis=0)
df.tail(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-08-15  140.050003  141.279999  137.229996  137.669998  137.669998
# 2023-08-16  137.190002  137.270004  135.009995  135.070007  135.070007
# 2023-08-17  135.460007  136.089996  133.529999  133.979996  133.979996
# 2023-08-18  131.619995  134.070007  131.149994  133.220001  133.220001
# 2023-08-21  133.740005  135.190002  132.710007  134.679993  134.679993
# 2023-08-22  135.080002  135.649994  133.729996  134.250000  134.250000
# 2023-08-23  134.500000  135.949997  133.220001  135.520004  135.520004
# 2023-08-24  136.399994  136.779999  131.830002  131.839996  131.839996
# ...

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5028.000000  5028.000000  5028.000000  5028.000000  5028.000000
# mean    137.796767   139.378418   136.207399   137.836020   136.369882
# std      68.664028    69.326698    67.948615    68.659197    67.753602
# min      35.994999    36.430000    35.500000    35.547501    34.163826
# 25%      89.209124    89.965876    88.074249    89.205248    89.139626
# 50%     126.360001   127.614998   124.907249   126.215000   125.100613
# 75%     164.634247   166.335003   162.931629   164.854630   163.938698
# max     361.750000   366.779999   352.440002   359.489990   358.730469
#
#              Volume
# count  5.028000e+03
# mean   6.273787e+07
# std    4.858669e+07
# min    6.936000e+06
# 25%    2.697888e+07
# 50%    4.865925e+07
# 75%    8.349078e+07
# max    4.265100e+08

# %%
# calculate summary statistics using .describe()
stats = AAPL.describe()

# plot the summary statistics in a table format
stats_table = pd.DataFrame(stats)
print(stats_table)
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1257.000000  1257.000000  1257.000000  1257.000000  1257.000000
# mean    113.917932   115.268787   112.651344   114.016659   112.566807
# std      46.823635    47.314390    46.352642    46.847467    47.122131
# min      35.994999    36.430000    35.500000    35.547501    34.163826
# 25%      64.192497    64.882500    63.237499    64.375000    62.610832
# 50%     127.142502   128.369995   125.849998   126.849998   125.260971
# 75%     150.630005   152.490005   149.220001   151.000000   150.059525
# max     196.240005   198.229996   195.279999   196.449997   196.185074
#
#              Volume
# count  1.257000e+03
# mean   1.087883e+08
# std    5.515362e+07
# min    3.145820e+07
# 25%    7.340180e+07
# 50%    9.440320e+07
# 75%    1.281382e+08
# max    4.265100e+08

# %%
# calculate summary statistics using .describe()
stats = AAPL.describe()

# create a matplotlib table
fig, ax = plt.subplots()
table = ax.table(cellText=np.round(stats.values, 2),
                 colLabels=stats.columns,
                 rowLabels=['Count', 'Mean', 'Std', 'Min', '25%', '50%', '75%', 'Max'],
                 loc='center')

# customize table properties
table.auto_set_font_size(True)
table.set_fontsize(14)
table.scale(1, 1.5)
ax.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
# calculate summary statistics using .describe()
stats = GOOG.describe()

# create a matplotlib table
fig, ax = plt.subplots()
table = ax.table(cellText=np.round(stats.values, 2),
                 colLabels=stats.columns,
                 rowLabels=['Count', 'Mean', 'Std', 'Min', '25%', '50%', '75%', 'Max'],
                 loc='center')

# customize table properties
table.auto_set_font_size(True)
table.set_fontsize(14)
table.scale(1, 1.5)
ax.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
# calculate summary statistics using .describe()
stats = MSFT.describe()

# create a matplotlib table
fig, ax = plt.subplots()
table = ax.table(cellText=np.round(stats.values, 2),
                 colLabels=stats.columns,
                 rowLabels=['Count', 'Mean', 'Std', 'Min', '25%', '50%', '75%', 'Max'],
                 loc='center')

# customize table properties
table.auto_set_font_size(True)
table.set_fontsize(14)
table.scale(1, 1.5)
ax.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
# calculate summary statistics using .describe()
stats = AMZN.describe()

# create a matplotlib table
fig, ax = plt.subplots()
table = ax.table(cellText=np.round(stats.values, 2),
                 colLabels=stats.columns,
                 rowLabels=['Count', 'Mean', 'Std', 'Min', '25%', '50%', '75%', 'Max'],
                 loc='center')

# customize table properties
table.auto_set_font_size(True)
table.set_fontsize(14)
table.scale(1, 1.5)
ax.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
GOOG.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1257.000000  1257.000000  1257.000000  1257.000000  1257.000000
# mean     93.155126    94.252923    92.159862    93.219095    93.219095
# std      30.247066    30.545467    29.934851    30.224561    30.224561
# min      48.695000    50.176998    48.505501    48.811001    48.811001
# 25%      62.648499    63.450001    62.131001    63.064499    63.064499
# 50%      91.200500    92.360001    90.289001    91.338501    91.338501
# 75%     119.120003   120.910004   117.709999   119.505997   119.505997
# max     151.863495   152.100006   149.887497   150.709000   150.709000
#
#              Volume
# count  1.257000e+03
# mean   3.018891e+07
# std    1.319024e+07
# min    6.936000e+06
# 25%    2.186420e+07
# 50%    2.686400e+07
# 75%    3.413800e+07
# max    1.241400e+08

# %%
GOOG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2018-08-29 to 2023-08-28
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          1257 non-null   float64
#  1   High          1257 non-null   float64
#  2   Low           1257 non-null   float64
#  3   Close         1257 non-null   float64
#  4   Adj Close     1257 non-null   float64
#  5   Volume        1257 non-null   int64
#  6   company_name  1257 non-null   object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 78.6+ KB

# %%
plt.figure(figsize=(15, 10))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, company in enumerate(company_list, 1):
    plt.subplot(2, 2, i)
    company['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {tech_list[i - 1]}")

plt.tight_layout()

# %%
AAPL.to_excel("AAPL_5years.xlsx")
GOOG.to_excel("GOOG_5years.xlsx")
MSFT.to_excel("MSFT_5years.xlsx")
AMZN.to_excel("AMZN_5years.xlsx")
